# %% [markdown]
# # Анализ тарифных планов компании «Мегалайн»

# %% [markdown]
# ## Загрузка данных и получение общей информации

# %% [markdown]
# В данной работе предусмотрено 5 взаимосвязанных датасетов - `calls`, `internet`, `messages`, `tariffs` и `users`.

# %% [markdown]
# Первым рассморим `calls`.

# %%
import pandas as pd
calls = pd.read_csv('datasets/calls.csv')

# %%
calls.head(5)
# Out:
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  object
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB

# %%
calls.hist('duration');

# %% [markdown]
# Большинство звонков имеют небольшую продолжительность, при этом с увеличением длительности их количество быстро уменьшается. Распределение данных скошено вправо и не является нормальным, что характерно для данных о телефонных звонках.

# %% [markdown]
# Далее - датасет `internet`, фактически содержащий информацию об интернет сессиях.

# %%
sessions = pd.read_csv("datasets/internet.csv")

# %%
sessions.head(5)
# Out:
#    Unnamed: 0      id  mb_used session_date  user_id
# 0           0  1000_0   112.95   2018-11-25     1000
# 1           1  1000_1  1052.81   2018-09-07     1000
# 2           2  1000_2  1197.26   2018-06-25     1000
# 3           3  1000_3   550.27   2018-08-22     1000
# 4           4  1000_4   302.56   2018-09-24     1000

# %%
sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    149396 non-null  int64
#  1   id            149396 non-null  object
#  2   mb_used       149396 non-null  float64
#  3   session_date  149396 non-null  object
#  4   user_id       149396 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB

# %%
sessions.hist('mb_used');

# %% [markdown]
# Большая часть интернет-сессий характеризуется небольшим объёмом потраченного трафика. Распределение имеет правостороннюю асимметрию: по мере увеличения количества использованных мегабайт число сессий уменьшается, при этом встречаются редкие сессии с высоким потреблением трафика.

# %% [markdown]
# Следующий - датасет `messages`.

# %%
messages = pd.read_csv("datasets/messages.csv")

# %%
messages.head(5)
# Out:
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  object
#  2   user_id       123036 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB

# %% [markdown]
# Датасет `tariffs`.

# %%
tariffs = pd.read_csv("datasets/tariffs.csv")

# %%
tariffs
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra

# %%
tariffs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   rub_monthly_fee        2 non-null      int64
#  4   rub_per_gb             2 non-null      int64
#  5   rub_per_message        2 non-null      int64
#  6   rub_per_minute         2 non-null      int64
#  7   tariff_name            2 non-null      object
# dtypes: int64(7), object(1)
# memory usage: 260.0+ bytes

# %% [markdown]
# Датасет представляет собой 2 строчки с признаками, характеризующими тарифы.

# %% [markdown]
# Последним будет загружен датасет `users`.

# %%
users = pd.read_csv("datasets/users.csv")

# %%
users.head(5)
# Out:
#    user_id  age churn_date         city first_name  last_name    reg_date  \
# 0     1000   52        NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1     1001   41        NaN       Москва       Иван       Ежов  2018-11-01
# 2     1002   59        NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3     1003   23        NaN       Москва      Белла   Белякова  2018-08-17
# 4     1004   68        NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart
# 3  ultra
# 4  ultra

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Приведем столбцы
#
# - `reg_date` из таблицы `users`
# - `churn_date` из таблицы `users`
# - `call_date` из таблицы `calls`
# - `message_date` из таблицы `messages`
# - `session_date` из таблицы `sessions`
#
# к новому типу с помощью метода `to_datetime()`.

# %%
# users['reg_date'] = pd.to_datetime(users['reg_date'], format="%Y-%m-%dT%H:%M:%S") 
# users['churn_date'] = pd.to_datetime(users['churn_date'], format="%Y-%m-%dT%H:%M:%S") 

# calls['call_date'] = pd.to_datetime(calls['call_date'], format="%Y-%m-%d") 

# messages['message_date'] = pd.to_datetime(messages['message_date'], format="%Y-%m-%dT%H:%M:%S") 
# sessions['session_date'] = pd.to_datetime(sessions['session_date'], format="%Y-%m-%dT%H:%M:%S")

# %%
for df, col in [
    (users, 'reg_date'),
    (users, 'churn_date'),
    (calls, 'call_date'),
    (messages, 'message_date'),
    (sessions, 'session_date')
]:
    df[col] = pd.to_datetime(df[col])

# %% [markdown]
# В данных предусмотрены звонки с нулевой продолжительностью, таким образом обозначены пропущенные звонки, поэтому их не нужно удалять.

# %% [markdown]
# В столбце `duration` датафрейма `calls` значения дробные. Округлим значения столбца `duration` вверх с помощью метода `numpy.ceil()` и приведем столбец `duration` к типу `int`.

# %%
import numpy as np

calls['duration'] = (np.ceil(calls['duration'])).astype('int')

# %% [markdown]
# Удалим столбец `Unnamed: 0` из датафрейма `sessions`. Столбец с таким названием возникает, когда данные сохраняют с указанием индекса (`df.to_csv(..., index=column)`). Он сейчас не понадобится.

# %%
sessions = sessions.drop("Unnamed: 0", axis=1)

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# Создадим столбцы `month` в датафреймах `calls`, `messages` и `sessions` с номером месяца из столбца из соответствующих столбцов в этих дата фреймах.

# %%
calls['month'] = calls['call_date'].dt.month 
messages['month'] = messages['message_date'].dt.month
sessions['month'] = sessions['session_date'].dt.month

# %% [markdown]
# Посчитаем количество сделанных звонков разговора для каждого пользователя по месяцам.

# %%
calls_per_month = calls.groupby(['user_id', 'month']).agg(calls=('duration', 'count'))

# %%
calls_per_month.head(30)
# Out:
#                calls
# user_id month
# 1000    5         22
#         6         43
#         7         47
#         8         52
#         9         58
#         10        57
#         11        43
#         12        46
# 1001    11        59
#         12        63
# 1002    6         15
#         7         26
#         8         42
#         9         36
#         10        33
#         11        32
#         12        33
# 1003    8         55
#         9        134
#         10       108
#         11       115
#         12       108
# 1004    5          9
#         6         31
#         7         22
#         8         19
#         9         26
#         10        29
#         11        19
#         12        21

# %% [markdown]
# Посчитаем количество израсходованных минут разговора для каждого пользователя по месяцам и сохраним в переменную `minutes_per_month`

# %%
minutes_per_month = calls.groupby(['user_id', 'month']).agg(minutes=('duration', 'sum'))

# %%
minutes_per_month.head(30)
# Out:
#                minutes
# user_id month
# 1000    5          159
#         6          172
#         7          340
#         8          408
#         9          466
#         10         350
#         11         338
#         12         333
# 1001    11         430
#         12         414
# 1002    6          117
#         7          214
#         8          289
#         9          206
#         10         212
#         11         243
#         12         236
# 1003    8          380
#         9          961
#         10         855
#         11         824
#         12         802
# 1004    5           35
#         6          171
#         7          135
#         8          137
#         9          117
#         10         145
#         11         117
#         12         130

# %% [markdown]
# Посчитаем количество отправленных сообщений по месяцам для каждого пользователя и сохраним в переменную `messages_per_month`.

# %%
messages
# Out:
#               id message_date  user_id
# 0         1000_0   2018-06-27     1000
# 1         1000_1   2018-10-08     1000
# 2         1000_2   2018-08-04     1000
# 3         1000_3   2018-06-16     1000
# 4         1000_4   2018-12-05     1000
# ...          ...          ...      ...
# 123031  1499_179   2018-12-12     1499
# 123032  1499_180   2018-09-28     1499
# 123033  1499_181   2018-09-27     1499
# 123034  1499_182   2018-11-15     1499
# 123035  1499_183   2018-11-16     1499
#
# [123036 rows x 3 columns]

# %%
messages_per_month = messages.groupby(['user_id', 'month']).agg(messages=('month', 'count'))

# %%
messages_per_month.head(30)
# Out:
#                messages
# user_id month
# 1000    5            22
#         6            60
#         7            75
#         8            81
#         9            57
#         10           73
#         11           58
#         12           70
# 1002    6             4
#         7            11
#         8            13
#         9             4
#         10           10
#         11           16
#         12           12
# 1003    8            37
#         9            91
#         10           83
#         11           94
#         12           75
# 1004    5            95
#         6           134
#         7           181
#         8           151
#         9           146
#         10          165
#         11          158
#         12          162
# 1005    1             7
#         2            38

# %% [markdown]
# Посчитаем количество потраченных мегабайт по месяцам для каждого пользователя и сохраним в переменную `sessions_per_month`.

# %%
sessions_per_month = sessions.groupby(['user_id', 'month']).agg({'mb_used': 'sum'})

# %%
sessions_per_month.head(30)
# Out:
#                 mb_used
# user_id month
# 1000    5       2253.49
#         6      23233.77
#         7      14003.64
#         8      14055.93
#         9      14568.91
#         10     14702.49
#         11     14756.47
#         12      9817.61
# 1001    11     18429.34
#         12     14036.66
# 1002    6      10856.82
#         7      17580.10
#         8      20319.26
#         9      16691.08
#         10     13888.25
#         11     18587.28
#         12     18113.73
# 1003    8       8565.21
#         9      12468.87
#         10     14768.14
#         11     11356.89
#         12     10121.53
# 1004    5      13403.98
#         6      17600.02
#         7      22229.58
#         8      28584.37
#         9      15109.03
#         10     18475.44
#         11     15616.02
#         12     18021.04

# %% [markdown]
# ### Анализ данных и подсчёт выручки

# %% [markdown]
# Объединяем все посчитанные выше значения в один датафрейм `user_behavior`.
# Для каждой пары "пользователь - месяц" будут доступны информация о тарифе, количестве звонков, сообщений и потраченных мегабайтах.

# %%
print(round(users['churn_date'].count() / users['churn_date'].shape[0] * 100, 2))
# Out:
# 7.6

# %% [markdown]
# Расторгли договор 7.6% клиентов из датасета

# %%
user_behavior = calls_per_month\
    .merge(messages_per_month, left_index=True, right_index=True, how='outer')\
    .merge(sessions_per_month, left_index=True, right_index=True, how='outer')\
    .merge(minutes_per_month, left_index=True, right_index=True, how='outer')\
    .reset_index()\
    .merge(users, how='left', left_on='user_id', right_on='user_id')\

user_behavior.head()
# Out:
#    user_id  month  calls  messages   mb_used  minutes  age churn_date  \
# 0     1000      5   22.0      22.0   2253.49    159.0   52        NaT
# 1     1000      6   43.0      60.0  23233.77    172.0   52        NaT
# 2     1000      7   47.0      75.0  14003.64    340.0   52        NaT
# 3     1000      8   52.0      81.0  14055.93    408.0   52        NaT
# 4     1000      9   58.0      57.0  14568.91    466.0   52        NaT
#
#         city first_name  last_name   reg_date tariff
# 0  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4  Краснодар     Рафаил  Верещагин 2018-05-25  ultra

# %% [markdown]
# Проверим пропуски в таблице `user_behavior` после объединения:

# %%
user_behavior.isna().sum()
# Out:
# user_id          0
# month            0
# calls           40
# messages       497
# mb_used         11
# minutes         40
# age              0
# churn_date    3027
# city             0
# first_name       0
# last_name        0
# reg_date         0
# tariff           0
# dtype: int64

# %% [markdown]
# Заполним образовавшиеся пропуски в данных:

# %%
user_behavior['calls'] = user_behavior['calls'].fillna(0)
user_behavior['minutes'] = user_behavior['minutes'].fillna(0)
user_behavior['messages'] = user_behavior['messages'].fillna(0)
user_behavior['mb_used'] = user_behavior['mb_used'].fillna(0)

# %% [markdown]
# Присоединяем информацию о тарифах

# %%
# переименование столбца tariff_name на более простое tariff

tariffs = tariffs.rename(
    columns={
        'tariff_name': 'tariff'
    }
)

# %%
user_behavior = user_behavior.merge(tariffs, on='tariff')

# %% [markdown]
# Считаем количество минут разговора, сообщений и мегабайт, превышающих включенные в тариф

# %%
user_behavior['paid_minutes'] = user_behavior['minutes'] - user_behavior['minutes_included']
user_behavior['paid_messages'] = user_behavior['messages'] - user_behavior['messages_included']
user_behavior['paid_mb'] = user_behavior['mb_used'] - user_behavior['mb_per_month_included']

for col in ['paid_messages', 'paid_minutes', 'paid_mb']:
    user_behavior.loc[user_behavior[col] < 0, col] = 0

# %% [markdown]
# Переводим превышающие тариф мегабайты в гигабайты и сохраняем в столбец `paid_gb`

# %%
user_behavior['paid_gb'] = np.ceil(user_behavior['paid_mb'] / 1024).astype(int)

# %% [markdown]
# Считаем выручку за минуты разговора, сообщения и интернет

# %%
user_behavior['cost_minutes'] = user_behavior['paid_minutes'] * user_behavior['rub_per_minute']
user_behavior['cost_messages'] = user_behavior['paid_messages'] * user_behavior['rub_per_message']
user_behavior['cost_gb'] = user_behavior['paid_gb'] * user_behavior['rub_per_gb']

# %% [markdown]
# Считаем помесячную выручку с каждого пользователя, она будет храниться в столбец `total_cost`

# %%
user_behavior['total_cost'] = \
      user_behavior['rub_monthly_fee']\
    + user_behavior['cost_minutes']\
    + user_behavior['cost_messages']\
    + user_behavior['cost_gb']

# %% [markdown]
# Датафрейм `stats_df` для каждой пары "месяц-тариф" будет хранить основные характеристики

# %%
# сохранение статистических метрик для каждой пары месяц-тариф
# в одной таблице stats_df (среднее значение, стандартное отклонение, медиана)

stats_df = user_behavior.pivot_table(
            index=['month', 'tariff'],\
            values=['calls', 'minutes', 'messages', 'mb_used'],\
            aggfunc=['mean', 'std', 'median']\
).round(2).reset_index()

stats_df.columns=['month', 'tariff', 'calls_mean', 'sessions_mean', 'messages_mean', 'minutes_mean',
                                     'calls_std',  'sessions_std', 'messages_std', 'minutes_std', 
                                     'calls_median', 'sessions_median', 'messages_median',  'minutes_median']

stats_df.head(10)
# Out:
#    month tariff  calls_mean  sessions_mean  messages_mean  minutes_mean  \
# 0      1  smart       27.68        8513.72          18.24        203.85
# 1      1  ultra       59.44       13140.68          33.78        428.11
# 2      2  smart       40.19       11597.05          24.09        298.69
# 3      2  ultra       41.54       11775.94          21.96        297.12
# 4      3  smart       54.32       15104.16          31.86        390.05
# 5      3  ultra       67.68       17535.55          32.30        489.65
# 6      4  smart       51.31       13462.18          30.74        367.13
# 7      4  ultra       64.09       16828.13          31.56        458.02
# 8      5  smart       55.24       15805.18          33.77        387.36
# 9      5  ultra       72.51       19363.15          37.85        510.33
#
#    calls_std  sessions_std  messages_std  minutes_std  calls_median  \
# 0      20.81       6444.68         16.20       154.23          20.5
# ...

# %% [markdown]
# Распределение среднего количества звонков по видам тарифов и месяцам

# %%
import seaborn as sns

ax = sns.barplot(x='month',
            y='calls_mean',
            hue="tariff",
            data=stats_df,
            palette=['lightblue', 'blue'])

ax.set_title('Распределение количества звонков по видам тарифов и месяцам')
ax.set(xlabel='Номер месяца', ylabel='Среднее количество звонков');

# %%
import matplotlib.pyplot as plt

user_behavior.groupby('tariff')['calls'].plot(kind='hist', bins=35, alpha=0.5)
plt.legend(['Smart', 'Ultra'])
plt.xlabel('Количество звонков')
plt.ylabel('Количество клиентов')
plt.show()

# %% [markdown]
# Пользователи тарифа Ultra в среднем совершают больше звонков, чем пользователи тарифа Smart, во всех месяцах года. Для обоих тарифов заметен рост среднего количества звонков к концу года. Распределение показывает, что у пользователей Ultra чаще встречаются большие значения количества звонков, что говорит о более активном использовании связи.

# %% [markdown]
# Распределение средней продолжительности звонков по видам тарифов и месяцам.

# %%
ax = sns.barplot(x='month',
            y='minutes_mean',
            hue="tariff",
            data=stats_df,
            palette=['lightblue', 'blue'])

ax.set_title('Распределение продолжительности звонков по видам тарифов и месяцам')
ax.set(xlabel='Номер месяца', ylabel='Средняя продолжительность звонков, мин');

# %%
import matplotlib.pyplot as plt

user_behavior.groupby('tariff')['minutes'].plot(
    kind='hist',
    bins=35,
    alpha=0.5
)

plt.xlabel('Количество минут')
plt.ylabel('Количество клиентов')
plt.title('Распределение количества минут разговора по тарифам')
plt.legend(['Smart', 'Ultra'])
plt.show()

# %% [markdown]
# Средняя длительность разговоров у абонентов тарифа Ultra больше, чем у абонентов тарифа Smart. В течение года пользователи обоих тарифов увеличивают среднюю продолжительность своих разговоров. Рост средней длительности разговоров у абонентов тарифа Smart равномерный в течение года. Пользователи тарифа Ultra не проявляют подобной линейной тенденции. Стоит отметить, что феврале у абонентов обоих тарифных планов наблюдались самые низкие показатели.

# %% [markdown]
# Распределение среднего количества сообщений по видам тарифов и месяцам

# %%
ax = sns.barplot(x='month',
            y='messages_mean',
            hue="tariff",
            data=stats_df,
            palette=['lightblue', 'blue']
)

ax.set_title('Распределение количества сообщений по видам тарифов и месяцам')
ax.set(xlabel='Номер месяца', ylabel='Среднее количество сообщений');

# %%
import matplotlib.pyplot as plt

user_behavior.groupby('tariff')['messages'].plot(
    kind='hist',
    bins=35,
    alpha=0.5
)

plt.xlabel('Количество сообщений')
plt.ylabel('Количество клиентов')
plt.title('Распределение количества сообщений по тарифам')
plt.legend(['Smart', 'Ultra'])
plt.show()

# %% [markdown]
# В среднем пользователи тарифа Ultra отправляют почти на 20 сообщений больше, чем пользователи тарифа Smart. Количество сообщений в течение года на обоих тарифах растет. Динамика по отправке сообщений схожа с тенденциями по длительности разговоров: в феврале отмечено наименьшее количество сообщений за год и пользователи тарифа Ultra также проявляют нелинейную положительную динамику.

# %%
ax = sns.barplot(x='month',
            y='sessions_mean',
            hue="tariff",
            data=stats_df,
            palette=['lightblue', 'blue']
)

ax.set_title('Распределение количества потраченного трафика (Мб) по видам тарифов и месяцам')
ax.set(xlabel='Номер месяца', ylabel='Среднее количество мегабайт');

# %% [markdown]
# Сравнение потраченных мегабайт среди пользователей тарифов Smart и Ultra

# %%
import matplotlib.pyplot as plt

user_behavior.groupby('tariff')['mb_used'].plot(
    kind='hist',
    bins=35,
    alpha=0.5
)

plt.xlabel('Объём интернет-трафика, Мб')
plt.ylabel('Количество клиентов')
plt.title('Распределение объёма интернет-трафика по тарифам')
plt.legend(['Smart', 'Ultra'])
plt.show()

# %% [markdown]
# В среднем пользователи тарифа «Ультра» потребляют больше интернет-трафика, чем пользователи тарифа «Смарт», во всех месяцах года. Для обоих тарифов наблюдается рост среднего объёма потребляемого трафика к концу года. Распределение показывает, что у пользователей тарифа «Ультра» чаще встречаются более высокие значения потребления интернета, что связано с большими лимитами тарифа. Меньше всего пользователи использовали интернет в январе, феврале и апреле. Чаще всего абоненты тарифа Smart тратят 15-17 Гб, а абоненты тарифного плана Ultra - 19-21 ГБ.

# %% [markdown]
# ### Проверка гипотез

# %% [markdown]
# Проверим гипотезу: `средняя выручка пользователей тарифов «Ультра» и «Смарт» различается`;
#
#
# ```
# H_0: Выручка (total_cost) пользователей "Ультра" = выручка (total_cost) пользователей "Смарт"`
# H_a: Выручка (total_cost) пользователей "Ультра" ≠ выручка (total_cost) пользователей "Смарт"`
# alpha = 0.05
# ```

# %%
from scipy import stats as st

# %%
results = st.ttest_ind(
    user_behavior[user_behavior['tariff'] == 'smart']['total_cost'],
    user_behavior[user_behavior['tariff'] == 'ultra']['total_cost'],
    equal_var=False)

alpha = .05

print('P-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Гипотезу отвергаем')
else:
    print('Не получилось отвергнуть гипотезу')
# Out:
# P-значение: 4.2606313931076085e-250
# Гипотезу отвергаем

# %%
smart_mean = user_behavior[user_behavior['tariff'] == 'smart']['total_cost'].mean()
ultra_mean = user_behavior[user_behavior['tariff'] == 'ultra']['total_cost'].mean()

print('Средняя выручка Smart:', smart_mean)
print('Средняя выручка Ultra:', ultra_mean)
print('Разница:', ultra_mean - smart_mean)
# Out:
# Средняя выручка Smart: 1289.9735307312696
# Средняя выручка Ultra: 2070.1522842639592
# Разница: 780.1787535326896

# %% [markdown]
# Средняя выручка пользователей тарифа «Ультра» составляет около 2707 руб., что заметно выше средней выручки пользователей тарифа «Смарт» — около 1290 руб. Разница между средними значениями составляет примерно 780 руб. В результате статистического теста нулевая гипотеза о равенстве средних выручек была отвергнута, что говорит о статистически значимом различии выручки между тарифами.

# %% [markdown]
# Проверим гипотезу: `пользователи из Москвы приносят больше выручки, чем пользователи из других городов`;
#
# ```
# H_0: Выручка (total_cost) пользователей из Москвы = выручка (total_cost) пользователей не из Москвы`
# H_1: Выручка (total_cost) пользователей из Москвы ≠ выручка (total_cost) пользователей не из Москвы`
# alpha = 0.05
# ```

# %%
results = st.ttest_ind(
    user_behavior[user_behavior['city'] == 'Москва']['total_cost'],
    user_behavior[user_behavior['city'] != 'Москва']['total_cost'],
    equal_var=False)

alpha = .05

print('P-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем гипотезу')
else:
    print('Не получилось отвергнуть гипотезу')
# Out:
# P-значение: 0.5257376663729298
# Не получилось отвергнуть гипотезу

# %% [markdown]
# В ходе проверки гипотезы о различии средней выручки пользователей из Москвы и других регионов статистически значимых различий выявлено не было. Значение p-value превышает уровень значимости 0.05, поэтому нулевая гипотеза не была отвергнута. Это означает, что на основе имеющихся данных нельзя утверждать, что пользователи из Москвы приносят компании большую выручку по сравнению с пользователями из других городов.

# %% [markdown]
# ## Вывод

# %% [markdown]
# В рамках проекта был проведён анализ поведения пользователей тарифных планов «Смарт» и «Ультра» компании «Мегалайн». Исследование показало, что пользователи тарифа «Ультра» в среднем активнее используют услуги связи и приносят компании более высокую выручку, чем пользователи тарифа «Смарт». Различие средней выручки между тарифами является статистически значимым. При этом значимых различий в выручке между пользователями из Москвы и других регионов выявлено не было. На основании проведённого анализа можно сделать вывод, что тариф «Ультра» является более прибыльным для компании.
